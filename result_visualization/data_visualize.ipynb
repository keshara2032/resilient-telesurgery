# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import numpy as np
import pandas as pd
import os
import glob
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from pathlib import Path

# %% [markdown]
# ## Load Dataset

# %%
df_list = []

path = os.getcwd()
labeled_data_glob = glob.glob(os.path.join(path, "./dataset/peg_transfer/labeled/gestures/*.csv"))
  
# loop over the list of kinematic csv files
for idx,f in enumerate(labeled_data_glob):
    # read the csv file
    data_df = pd.read_csv(f)
#     s1_df = data_df.loc[data_df['gesture'] == "S1"]
    
    label_file_name = f.split('\\')[-1]
    ax = data_df.reset_index().plot(kind='scatter', x='index', y='PSML_gripper_angle',
                                    c=data_df['gesture'].map({'S1':1,
                                                              'S2':2,
                                                              'S3':3,
                                                              'S4':4,
                                                              'S5':5,
                                                              'S6':6,
                                                              'S7':7}),
                                   colormap='viridis',
                                   title = label_file_name,
                                   legend = True)
    
#     s2_df = data_df.loc[data_df['gesture'] == "S2"]

#     s2_df.reset_index().plot(ax=ax, kind='scatter', x='index', y='PSML_gripper_angle', c="red")
    
    df_list.append(data_df)

df = pd.concat(df_list)

# s1_df = df.loc[df['gesture'] == "S1"]
# s2_df = df.loc[df['gesture'] == "S2"]
# s3_df = df.loc[df['gesture'] == "S3"]
# s4_df = df.loc[df['gesture'] == "S4"]
# s5_df = df.loc[df['gesture'] == "S5"]
# s6_df = df.loc[df['gesture'] == "S6"]
# s7_df = df.loc[df['gesture'] == "S7"]

# s1_df.to_csv("./dataset/peg_transfer/labeled/gestures/S1_all_trials.csv")
# s2_df.to_csv("./dataset/peg_transfer/labeled/gestures/S2_all_trials.csv")
# s3_df.to_csv("./dataset/peg_transfer/labeled/gestures/S3_all_trials.csv")
# s4_df.to_csv("./dataset/peg_transfer/labeled/gestures/S4_all_trials.csv")
# s5_df.to_csv("./dataset/peg_transfer/labeled/gestures/S5_all_trials.csv")
# s6_df.to_csv("./dataset/peg_transfer/labeled/gestures/S6_all_trials.csv")
# s7_df.to_csv("./dataset/peg_transfer/labeled/gestures/S7_all_trials.csv")
# Out:
# C:\Users\cjh9fw\AppData\Local\anaconda3\envs\keras-tt\lib\site-packages\pandas\plotting\_matplotlib\core.py:509: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = self.plt.figure(figsize=self.figsize)
